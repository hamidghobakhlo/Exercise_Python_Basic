# %% [markdown]
# # Operating System (OS) Library

# %%
import os

# %%
path ="./" 
list(os.walk(path))
# Out:
# [('./',
#   ['MiniProject_1'],
#   ['Boolean_Values.ipynb',
#    'comments.ipynb',
#    'conditions.ipynb',
#    'data_types.ipynb',
#    'dictionary.ipynb',
#    'for_loops.ipynb',
#    'function.ipynb',
#    'library_OS.ipynb',
#    'lists.ipynb',
#    'operators.ipynb',
#    'README.md',
#    'recursive_functions.ipynb',
#    'sets.ipynb',
#    'strings.ipynb',
#    'String_Formatting.ipynb',
#    'tuple.ipynb',
#    'User_Input.ipynb',
#    'variables.ipynb',
#    'while_loops.ipynb']),
#  ('./MiniProject_1', [], ['product.py'])]

# %%
path ="./" 
exts = set()
for path, dirs, files in os.walk(path):
    for f in files:
        ext = f.split(".")[-1]
        exts.add(ext)
print(exts)
# Out:
# {'ipynb', 'py', 'md'}
